# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("raw_dataset_2.csv")
df
# Out:
#                  طابع زمني  العمر  الجنس المؤهل العلمي  \
# 0     1:43:54 م 2024/08/13      21   ذكر     بكالوريوس
# 1     2:02:18 م 2024/08/13      21   ذكر     بكالوريوس
# 2     2:02:21 م 2024/08/13      21   ذكر     بكالوريوس
# 3     2:08:46 م 2024/08/13      21   ذكر     بكالوريوس
# 4     3:11:50 م 2024/08/13      22  أنثى     بكالوريوس
# ..                     ...     ...   ...           ...
# 100  10:36:30 م 2024/08/17      20  أنثى     بكالوريوس
# 101  10:43:35 م 2024/08/17      23  أنثى     بكالوريوس
# 102   2:20:53 م 2024/08/18      21  أنثى     بكالوريوس
# 103   9:26:34 م 2024/08/18      19   ذكر     بكالوريوس
# 104  11:54:16 ص 2024/08/19      19   ذكر     بكالوريوس
#
#                         العمل مكان السكن  المحافظة  \
# 0                     لا أعمل       قرية     نابلس
# 1                     لا أعمل      مدينة     نابلس
# 2                     لا أعمل       قرية   قلقيلية
# 3                     لا أعمل      مدينة     نابلس
# 4                     لا أعمل       قرية     نابلس
# ..                        ...        ...       ...
# 100  أعمل في مجال التكنولوجيا      مدينة   قلقيلية
# 101                   لا أعمل       مخيم  رام الله
# 102       أعمل في مجالات أخرى      مدينة  رام الله
# 103                   لا أعمل      مدينة  رام الله
# 104  أعمل في مجال التكنولوجيا      مدينة  رام الله
#
#                               الكلية :  \
# 0    كلية الهندسة وتكنولوجيا المعلومات
# 1    كلية الهندسة وتكنولوجيا المعلومات
# 2    كلية الهندسة وتكنولوجيا المعلومات
# 3    كلية الهندسة وتكنولوجيا المعلومات
# 4    كلية الهندسة وتكنولوجيا المعلومات
# ..                                 ...
# 100  كلية الهندسة وتكنولوجيا المعلومات
# 101                        كلية العلوم
# 102  كلية الهندسة وتكنولوجيا المعلومات
# 103                      كلية الاقتصاد
# 104                                NaN
#
#      ما هو مستوى قبولك للسيارات ذاتية القيادة؟  \
# 0                                            1
# 1                                            5
# 2                                            2
# 3                                            2
# 4                                            3
# ..                                         ...
# 100                                          3
# 101                                          2
# 102                                          2
# 103                                          4
# 104                                          2
#
#     هل سبق لك ركبت سيارة من غير سائق؟  ...  \
# 0                                  لا  ...
# 1                                  لا  ...
# 2                                  لا  ...
# 3                                  لا  ...
# 4                                  لا  ...
# ..                                ...  ...
# 100                                لا  ...
# 101                                لا  ...
# 102                                لا  ...
# 103                                لا  ...
# 104                                لا  ...
#
#     تكلفة شراء سيارات ذاتية القيادة عالية جدا  \
# 0                                           4
# 1                                           5
# 2                                           4
# 3                                           5
# 4                                           5
# ..                                        ...
# 100                                         4
# 101                                         5
# 102                                         4
# 103                                         1
# 104                                         5
#
#     تكلفة القطع الخاصة في السيارات ذاتية القيادة غالية جدا  \
# 0                                                    4
# 1                                                    4
# 2                                                    4
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 100                                                  4
# 101                                                  4
# 102                                                  4
# 103                                                  2
# 104                                                  3
#
#      تكلفة تصليح السيارات ذاتية القيادة كبيرة جدا  \
# 0                                               5
# 1                                               4
# 2                                               4
# 3                                               5
# 4                                               5
# ..                                            ...
# 100                                             4
# 101                                             4
# 102                                             4
# 103                                             2
# 104                                             3
#
#      كل السيارات ذاتية القيادة هي سيارات كهربائية فقط  \
# 0                                                   1
# 1                                                   5
# 2                                                   2
# 3                                                   5
# 4                                                   3
# ..                                                ...
# 100                                                 3
# 101                                                 4
# 102                                                 4
# 103                                                 1
# 104                                                 5
#
#      السيارات ذاتية القيادة أمن من سيارات العادية  \
# 0                                               1
# 1                                               5
# 2                                               1
# 3                                               1
# 4                                               3
# ..                                            ...
# 100                                             3
# 101                                             2
# 102                                             4
# 103                                             3
# 104                                             2
#
#      السيارات بدون سائق ستقلل من حوادث المرور  \
# 0                                           2
# 1                                           5
# 2                                           1
# 3                                           1
# 4                                           3
# ..                                        ...
# 100                                         4
# 101                                         2
# 102                                         2
# 103                                         3
# 104                                         2
#
#      السيارات بدون سائق ستساعد في تقليل التلوث  عدم توافر القطع  \
# 0                                            4                5
# 1                                            5                4
# 2                                            1                5
# 3                                            5                5
# 4                                            4                4
# ..                                         ...              ...
# 100                                          4                4
# 101                                          4                4
# 102                                          3                4
# 103                                          4                5
# 104                                          2                4
#
#      عدم توفر الاشخاص القادرة على صيانة  \
# 0                                     5
# 1                                     3
# 2                                     5
# 3                                     5
# 4                                     4
# ..                                  ...
# 100                                   3
# 101                                   5
# 102                                   4
# 103                                   5
# 104                                   4
#
#      تشكل عدم التزام الناس بقوانين القيادة عقبة في وجه قبول سيارات ذاتية القيادة
# 0                                                    1
# 1                                                    5
# 2                                                    5
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 100                                                  4
# 101                                                  4
# 102                                                  4
# 103                                                  5
# 104                                                  5
#
# [105 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# طابع زمني                                                                        0
# العمر                                                                            0
# الجنس                                                                            0
# المؤهل العلمي                                                                    0
# العمل                                                                            0
# مكان السكن                                                                       0
# المحافظة                                                                         0
# الكلية :                                                                         3
# ما هو مستوى قبولك للسيارات ذاتية القيادة؟                                        0
# هل سبق لك ركبت سيارة من غير سائق؟                                                0
# هل تمتلك رخصة قيادة سيارة؟                                                       0
# هل تمتلك سيارة؟                                                                  0
# البنية التحتية هي العقبة الرئيسية لقبول السيارات ذاتية القيادة.                  0
# الفجوة في قدرة الناس على إصلاح السيارات الكهربائية هي مشكلة رئيسية.              0
# إحدى المشاكل التي تواجه السيارة بدون سائق هي عدم ثقة الناس بالذكاء الاصطناعي.    0
# تشعر بالخوف اتجاه السلامة في السيارات ذاتية القيادة                              0
# تشعر بالخوف اتجاه تكاليف الصيانة في السيارات ذاتية القيادة                       0
# تشعر بالخوف اتجاه القرصنة و التهكير في السيارات ذاتية القيادة                    0
#  السيارات ذاتية القيادة سوف تسرق بعض الوظائف                                     0
# اثق في التكنولوجيا                                                               0
# لدي معرفة سابقة عن السيارات ذاتية القيادة                                        0
# أفكر في شراء سيارة بدون سائق في المستقبل                                         0
# أشعر بالقلق بشأن التداعيات المتعلقة بالخصوصية للسيارات بدون سائق                 0
# تكلفة شراء سيارات ذاتية القيادة عالية جدا                                        0
# تكلفة القطع الخاصة في السيارات ذاتية القيادة غالية جدا                           0
# تكلفة تصليح السيارات ذاتية القيادة كبيرة جدا                                     0
# كل السيارات ذاتية القيادة هي سيارات كهربائية فقط                                 0
# السيارات ذاتية القيادة أمن من سيارات العادية                                     0
# السيارات بدون سائق ستقلل من حوادث المرور                                         0
# السيارات بدون سائق ستساعد في تقليل التلوث                                        0
# عدم توافر القطع                                                                  0
# عدم توفر الاشخاص القادرة على صيانة                                               0
# تشكل عدم التزام الناس بقوانين القيادة عقبة في وجه قبول سيارات ذاتية القيادة      0
# dtype: int64

# %%
df.columns=["طابع_زمني",
"العمر",
"الجنس",
"المؤهل_العلمي",
"العمل",
"السكن",
"المحافظة",
"الكلية",
"مستوى_قبول",
"ركبت_سيارة",
"تمتلك_رخصة_قيادة_سيارة",
"تمتلك_سيارة",
"البنية_التحتية",
"الفجوة_في_إصلاح",
"عدم_ثقة_AI",
"safety",
"تكاليف_صيانة",
"fear_of_hacker",
"السيارات_ذاتية_القيادة_سوف_تسرق_بعض_الوظائف",
"اثق_في_التكنولوجيا",
"معرفة_السيارات_ذاتية_القيادة",
"أفكر_في_شراء",
"القلق_الخصوصية",
"تكلفة_شراء_سيارات",
"تكلفة_القطع",
"تكلفة_تصليح",
"is_elctric",
"safer",
"less_accident",
"less_population",
"no_pieaces",
"no_rapairer",
"عدم_التزام_قوانين"]

# %%
df.head()
# Out:
#               طابع_زمني  العمر الجنس المؤهل_العلمي    العمل  السكن المحافظة  \
# 0  1:43:54 م 2024/08/13     21   ذكر     بكالوريوس  لا أعمل   قرية    نابلس
# 1  2:02:18 م 2024/08/13     21   ذكر     بكالوريوس  لا أعمل  مدينة    نابلس
# 2  2:02:21 م 2024/08/13     21   ذكر     بكالوريوس  لا أعمل   قرية  قلقيلية
# 3  2:08:46 م 2024/08/13     21   ذكر     بكالوريوس  لا أعمل  مدينة    نابلس
# 4  3:11:50 م 2024/08/13     22  أنثى     بكالوريوس  لا أعمل   قرية    نابلس
#
#                               الكلية  مستوى_قبول ركبت_سيارة  ...  \
# 0  كلية الهندسة وتكنولوجيا المعلومات           1         لا  ...
# 1  كلية الهندسة وتكنولوجيا المعلومات           5         لا  ...
# 2  كلية الهندسة وتكنولوجيا المعلومات           2         لا  ...
# 3  كلية الهندسة وتكنولوجيا المعلومات           2         لا  ...
# 4  كلية الهندسة وتكنولوجيا المعلومات           3         لا  ...
#
#   تكلفة_شراء_سيارات تكلفة_القطع  تكلفة_تصليح  is_elctric  safer  \
# 0                 4           4            5           1      1
# 1                 5           4            4           5      5
# 2                 4           4            4           2      1
# 3                 5           5            5           5      1
# 4                 5           5            5           3      3
#
#    less_accident  less_population  no_pieaces  no_rapairer  عدم_التزام_قوانين
# 0              2                4           5            5                  1
# 1              5                5           4            3                  5
# 2              1                1           5            5                  5
# 3              1                5           5            5                  5
# 4              3                4           4            4                  4
#
# [5 rows x 33 columns]

# %%
df["الكلية"]=df["الكلية"].fillna("-")

# %%
df.isnull().sum()
# Out:
# طابع_زمني                                      0
# العمر                                          0
# الجنس                                          0
# المؤهل_العلمي                                  0
# العمل                                          0
# السكن                                          0
# المحافظة                                       0
# الكلية                                         0
# مستوى_قبول                                     0
# ركبت_سيارة                                     0
# تمتلك_رخصة_قيادة_سيارة                         0
# تمتلك_سيارة                                    0
# البنية_التحتية                                 0
# الفجوة_في_إصلاح                                0
# عدم_ثقة_AI                                     0
# safety                                         0
# تكاليف_صيانة                                   0
# fear_of_hacker                                 0
# السيارات_ذاتية_القيادة_سوف_تسرق_بعض_الوظائف    0
# اثق_في_التكنولوجيا                             0
# معرفة_السيارات_ذاتية_القيادة                   0
# أفكر_في_شراء                                   0
# القلق_الخصوصية                                 0
# تكلفة_شراء_سيارات                              0
# تكلفة_القطع                                    0
# تكلفة_تصليح                                    0
# is_elctric                                     0
# safer                                          0
# less_accident                                  0
# less_population                                0
# no_pieaces                                     0
# no_rapairer                                    0
# عدم_التزام_قوانين                              0
# dtype: int64

# %%
df=df.dropna()

# %%
arabic_to_western = {
    '٠': '0', '١': '1', '٢': '2', '٣': '3', '٤': '4',
    '٥': '5', '٦': '6', '٧': '7', '٨': '8', '٩': '9'
}

# Function to replace Arabic-Indic numerals with Western numerals
def convert_arabic_to_western(text):
    # Ensure the input is a string
    text = str(text)
    text.replace("سنه","")
    # Replace each Arabic-Indic digit with the corresponding Western digit
    for arabic_digit, western_digit in arabic_to_western.items():
        
        text = text.replace(arabic_digit, western_digit)
        if (text=="40 سنه"):
            text="40"
    return text
df['العمر'] = df['العمر'].apply(convert_arabic_to_western)

# Convert to integer if necessary and check if the number is in the range [0, 100]
df['العمر'] = df['العمر'].astype(float)

# %%
df = df.replace("لا", "0")
df = df.replace("نعم", "1")
df.to_csv("cleaned_dataset_2.csv")

# %%
df
# Out:
#                  طابع_زمني  العمر الجنس المؤهل_العلمي  \
# 0     1:43:54 م 2024/08/13   21.0   ذكر     بكالوريوس
# 1     2:02:18 م 2024/08/13   21.0   ذكر     بكالوريوس
# 2     2:02:21 م 2024/08/13   21.0   ذكر     بكالوريوس
# 3     2:08:46 م 2024/08/13   21.0   ذكر     بكالوريوس
# 4     3:11:50 م 2024/08/13   22.0  أنثى     بكالوريوس
# ..                     ...    ...   ...           ...
# 100  10:36:30 م 2024/08/17   20.0  أنثى     بكالوريوس
# 101  10:43:35 م 2024/08/17   23.0  أنثى     بكالوريوس
# 102   2:20:53 م 2024/08/18   21.0  أنثى     بكالوريوس
# 103   9:26:34 م 2024/08/18   19.0   ذكر     بكالوريوس
# 104  11:54:16 ص 2024/08/19   19.0   ذكر     بكالوريوس
#
#                         العمل  السكن  المحافظة  \
# 0                     لا أعمل   قرية     نابلس
# 1                     لا أعمل  مدينة     نابلس
# 2                     لا أعمل   قرية   قلقيلية
# 3                     لا أعمل  مدينة     نابلس
# 4                     لا أعمل   قرية     نابلس
# ..                        ...    ...       ...
# 100  أعمل في مجال التكنولوجيا  مدينة   قلقيلية
# 101                   لا أعمل   مخيم  رام الله
# 102       أعمل في مجالات أخرى  مدينة  رام الله
# 103                   لا أعمل  مدينة  رام الله
# 104  أعمل في مجال التكنولوجيا  مدينة  رام الله
#
#                                 الكلية  مستوى_قبول ركبت_سيارة  ...  \
# 0    كلية الهندسة وتكنولوجيا المعلومات           1          0  ...
# 1    كلية الهندسة وتكنولوجيا المعلومات           5          0  ...
# 2    كلية الهندسة وتكنولوجيا المعلومات           2          0  ...
# 3    كلية الهندسة وتكنولوجيا المعلومات           2          0  ...
# 4    كلية الهندسة وتكنولوجيا المعلومات           3          0  ...
# ..                                 ...         ...        ...  ...
# 100  كلية الهندسة وتكنولوجيا المعلومات           3          0  ...
# 101                        كلية العلوم           2          0  ...
# 102  كلية الهندسة وتكنولوجيا المعلومات           2          0  ...
# 103                      كلية الاقتصاد           4          0  ...
# 104                                  -           2          0  ...
#
#     تكلفة_شراء_سيارات تكلفة_القطع  تكلفة_تصليح  is_elctric  safer  \
# 0                   4           4            5           1      1
# 1                   5           4            4           5      5
# 2                   4           4            4           2      1
# 3                   5           5            5           5      1
# 4                   5           5            5           3      3
# ..                ...         ...          ...         ...    ...
# 100                 4           4            4           3      3
# 101                 5           4            4           4      2
# 102                 4           4            4           4      4
# 103                 1           2            2           1      3
# 104                 5           3            3           5      2
#
#      less_accident  less_population  no_pieaces  no_rapairer  \
# 0                2                4           5            5
# 1                5                5           4            3
# 2                1                1           5            5
# 3                1                5           5            5
# 4                3                4           4            4
# ..             ...              ...         ...          ...
# 100              4                4           4            3
# 101              2                4           4            5
# 102              2                3           4            4
# 103              3                4           5            5
# 104              2                2           4            4
#
#      عدم_التزام_قوانين
# 0                    1
# 1                    5
# 2                    5
# 3                    5
# 4                    4
# ..                 ...
# 100                  4
# 101                  4
# 102                  4
# 103                  5
# 104                  5
#
# [105 rows x 33 columns]
